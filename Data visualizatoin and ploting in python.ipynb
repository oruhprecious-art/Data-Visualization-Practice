# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\oruh precious\appdata\local\anaconda3\lib\site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\oruh precious\appdata\local\anaconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\oruh precious\appdata\local\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\oruh precious\appdata\local\anaconda3\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\oruh precious\appdata\local\anaconda3\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\oruh precious\appdata\local\anaconda3\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\oruh precious\appdata\local\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\oruh precious\appdata\local\anaconda3\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\oruh precious\appdata\local\anaconda3\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\oruh precious\appdata\local\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\oruh precious\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np

# prepare data
x = np.linspace(0, 10, 100)
y = 2 * x + 1

# create the line plot
plt.plot(x, y)

# add the grid
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line plot Example')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# prepare data
categories = ['Category A', 'Category B', 'Category C', 'Category D']
values = (23, 45, 26, 12)

# create the bar plot
plt.bar(categories, values)

# customize the plot
plt.title('Bar Plot Example')
plt.xlabel('categories')
plt.ylabel('values')

plt.savefig('bar_example.png')

plt.show()
